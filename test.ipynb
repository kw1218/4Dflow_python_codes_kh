# %%
import sys
import os
import os.path as osp
import numpy as np
from glob import glob
import pyvista as pv
import descriptors_utils as dut
from matplotlib import pyplot as plt
import pandas as pd

# %%
rootDir=r'D:\InletProfileStudy\SSM\Output_2024\Circular\synthetic_cohort_first8modes\018'
vtp_path = osp.join(rootDir, '*.vtp')

# %%
input_vtps = pv.read(sorted(glob((vtp_path))))

# %%
len(input_vtps)
# Out:
# 25

# %%
FJA_all=dut.compute_flow_jet_angle_kh(input_vtps)

# %%
FJA_all
# Out:
# {'fja(t)': [8.180764354670846,
#   15.590129639163958,
#   8.933923679875264,
#   9.18995385068237,
#   12.411269426572561,
#   15.999150543416352,
#   18.899418550801542,
#   30.99929378846283,
#   82.60901077063625,
#   107.08990904116013,
#   104.0503602471459,
#   84.24541614415348,
#   90.87206997089034,
#   102.9634979292525,
#   114.9621948612308,
#   14.580764022798839,
#   103.24939422175358,
#   14.765323892394024,
#   46.87745140142828,
#   8.180764354670846],
#  'fja_systole': 8.933923679875264,
#  'fja_max': 114.9621948612308,
#  'fja_mean': 49.732503034558036}

# %%
input_vtps[0].compute_normals()['Normals'].mean(0)
# Out:
# pyvista_ndarray([ 0.72835493,  0.15639845, -0.66708714], dtype=float32)

# %%
FDA_all=dut.compute_flow_dispersion(input_vtps)

# %%
FDA_all
# Out:
# {'fdi(t)': [14.07752271516461,
#   16.53022811289868,
#   18.15794535533544,
#   17.319268872118837,
#   18.045933625596735,
#   15.300181935193335,
#   11.346437503083818,
#   9.106062897813947,
#   7.285328310897615,
#   19.57900563462609,
#   8.046868616690936,
#   11.945034246976693,
#   5.006498662233292,
#   9.064517565945147,
#   8.348394178376509,
#   10.15938477517305,
#   12.057055141440484,
#   8.681437370028789,
#   14.07752271516461,
#   14.07752271516461],
#  'fdi_systole': 17.319268872118837,
#  'fdi_mean': 12.41060754749616,
#  'fdi_max': 19.57900563462609}
