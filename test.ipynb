# %%
import sys
import os
import os.path as osp
import numpy as np
from glob import glob
import pyvista as pv
import descriptors_utils as dut
from matplotlib import pyplot as plt
import pandas as pd

# %%
rootDir=r'D:\InletProfileStudy\SSM\Output_2024\Circular\mean_profile'
vtp_path = osp.join(rootDir, '*.vtp')

# %%
input_vtps = pv.read(sorted(glob((vtp_path))))

# %%
len(input_vtps)
# Out:
# 20

# %%
FJA_all=dut.compute_flow_jet_angle_kh(input_vtps)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 FJA_all=dut.compute_flow_jet_angle_kh(input_vtps)
#
# AttributeError: module 'descriptors_utils' has no attribute 'compute_flow_jet_angle_kh'

# %%
FJA_all
# Out:
# {'fja(t)': [20.942736820900155,
#   5.974003101421212,
#   4.154184031739495,
#   3.9532894534057945,
#   5.353315102606505,
#   8.715877757541179,
#   16.176379948867066,
#   48.414971564955025,
#   129.43350464911376,
#   170.43198020226353,
#   142.66295850661444,
#   136.11040743684066,
#   138.83980076667314,
#   144.7446178326164,
#   146.123498720051,
#   140.40351826327782,
#   146.79037166751658,
#   61.49124580298602,
#   91.71178407227704,
#   20.942736820900155],
#  'fja_systole': 4.154184031739495,
#  'fja_max': 170.43198020226353,
#  'fja_mean': 79.16855912612834}
